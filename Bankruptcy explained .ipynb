# %% [markdown]
# # Bankruptcy Explained
#
# ## Introduction

# %% [markdown]
# Cette étude traitera la prédiction de faillite d'une entreprise. Le but de la prédiction de faillite est de développer un modèle prédictif qui combine différentes mesures économétriques et permet de prévoir la situation financière d'une entreprise.
#
# C'est un vaste domaine de la finance et de l'économétrie qui combine les connaissances d'experts sur le phénomène et les données historiques des entreprises prospères et non prospères.
#
# Généralement, les entreprises sont quantifiées par de nombreux indicateurs qui décrivent leur situation commerciale et qui sont ensuite utilisés pour induire un modèle mathématique à partir d'observations passées.
#
# Différentes questions sont associées à la prévision de faillite. Deux problèmes principaux sont les suivants. Tout d'abord, les indicateurs économétriques décrivant l'état de l'entreprise sont proposés par des experts du domaine. Cependant, il n'est pas très clair comment les combiner en un puissant modèle. Deuxièmement, les observations historiques utilisées pour former un modèle sont habituellement influencées par le phénomène de déséquilibre des données, parce qu'il y a généralement beaucoup plus d'entreprises qui réussissent que celles qui sont en faillite. Par conséquent, le modèle formé tend à prédire que les entreprises réussies (classe majoritaire), même lorsque certaines d'entre elles sont des entreprises en difficulté. Ces deux questions influent surtout sur le processus de la la capacité de prédiction finale du modèle.

# %% [markdown]
# ## Dataset

# %% [markdown]
# Dans cette étude, nous avons utilisé la dataset fournie dans [https://archive.ics.uci.edu/ml/datasets/Polish+companies+bankruptcy+data]. Cet dataset concerne la prévision des faillites des entreprises polonaises. Les entreprises en faillite ont été analysées au cours de la période 2000-2012, tandis que les entreprises encore en activité ont été évaluées de 2007 à 2013. En se basant sur cette dataset, cinq cas de classification ont été distingués, qui dépendent de la période de prévision :
# - 1re année : les données contiennent les taux financiers de la 1re année de la période de prévision et l'étiquette de classe correspondante qui indique le statut de faillite après **5** ans. Les données contiennent **7027** cas (états financiers), **271** représentent des entreprises en faillite, **6756** entreprises qui n'ont pas fait faillite au cours de la période de prévision,
# - 2e année : les données contiennent les taux financiers de la 2e année de la période de prévision et l'étiquette de classe correspondante qui indique le statut de faillite après **4** ans. Les données contiennent **10173** cas (états financiers), **400** représentent des entreprises en faillite, **9773** entreprises qui n'ont pas fait faillite au cours de la période de prévision,
# - 3e année : les données contiennent les taux financiers de la 3e année de la période de prévision et l'étiquette de classe correspondante qui indique le statut de faillite après **3** ans. Les données contiennent **10503** cas (états financiers), **495** représentent des entreprises en faillite, **10008** entreprises qui n'ont pas fait faillite au cours de la période de prévision,
# - 4e année : les données contiennent les taux financiers de la 4e année de la période de prévision et l'étiquette de classe correspondante qui indique le statut de faillite après **2** ans. Les données contiennent **9792** cas (états financiers), **515** représentent des entreprises en faillite, **9277** entreprises qui n'ont pas fait faillite au cours de la période de prévision,
# - 5e année - les données contiennent les taux financiers de la 5e année de la période de prévision et l'étiquette de classe correspondante qui indique le statut de faillite après **1** an. Les données contiennent **5910** cas (états financiers), **410** représentent des entreprises en faillite, **5500** entreprises qui n'ont pas fait faillite au cours de la période de prévision.
#
# Les indicateurs financiers considérés dans cette étude sont décrits en détail dans le tableau ci-dessous.

# %% [markdown]
# |ID |Description   |ID  |Description   |
# |--:|---|---|---|
# |X1|net profit / total assets|X33|operating expenses / short-term liabilities|
# |X2|total liabilities / total assets|X34|operating expenses / total liabilities|
# |X3|working capital / total assets|X35|profit on sales / total assets|
# |X4|current assets / short-term liabilities|X36|total sales / total assets|
# |X5|[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365|X37|(current assets - inventories) / long-term liabilities|
# |X6|retained earnings / total assets|X38|constant capital / total assets|
# |X7|EBIT / total assets|X39|profit on sales / sales|
# |X8|book value of equity / total liabilities|X40|(current assets - inventory - receivables) / short-term liabilities|
# |X9|sales / total assets|X41|total liabilities / ((profit on operating activities + depreciation) * (12/365))|
# |X10|equity / total assets|X42|profit on operating activities / sales|
# |X11|(gross profit + extraordinary items + financial expenses) / total assets|X43|rotation receivables + inventory turnover in days|
# |X12|gross profit / short-term liabilities|X44|(receivables * 365) / sales|
# |X13|(gross profit + depreciation) / sales|X45|net profit / inventory|
# |X14|(gross profit + interest) / total assets|X46|(current assets - inventory) / short-term liabilities|
# |X15|(total liabilities * 365) / (gross profit + depreciation)|X47|(inventory * 365) / cost of products sold|
# |X16|(gross profit + depreciation) / total liabilities|X48|EBITDA (profit on operating activities - depreciation) / total assets|
# |X17|total assets / total liabilities|X49|EBITDA (profit on operating activities - depreciation) / sales|
# |X18|gross profit / total assets|X50|current assets / total liabilities|
# |X19|gross profit / sales|X51|short-term liabilities / total assets|
# |X20|(inventory * 365) / sales|X52|(short-term liabilities * 365) / cost of products sold)|
# |X21|sales (n) / sales (n-1)|X53|equity / fixed assets|
# |X22|profit on operating activities / total assets|X54|constant capital / fixed assets|
# |X23|net profit / sales|X55|working capital|
# |X24|gross profit (in 3 years) / total assets|X56|(sales - cost of products sold) / sales|
# |X25|(equity - share capital) / total assets|X57|(current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)|
# |X26|(net profit + depreciation) / total liabilities|X58|total costs /total sales|
# |X27|profit on operating activities / financial expenses|X59|long-term liabilities / equity|
# |X28|working capital / fixed assets|X60|sales / inventory|
# |X29|logarithm of total assets|X61|sales / receivables|
# |X30|(total liabilities - cash) / sales|X62|(short-term liabilities *365) / sales|
# |X31|(gross profit + interest) / sales|X63|sales / short-term liabilities|
# |X32|(current liabilities * 365) / cost of products sold|X64|sales / fixed assets|

# %% [markdown]
# ## Exploration des données

# %% [markdown]
# L'ensemble de données étant fourni au format arff, il fallait le convertir au format csv afin de pouvoir l'explorer à l'aide de la bibliothèque Panda.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint
from scipy.io import arff
from itertools import starmap
import seaborn as sns
import logging

loglevel = "DEBUG"
numeric_level = getattr(logging, loglevel.upper(), None)
if not isinstance(numeric_level, int):
    raise ValueError('Invalid log level: %s' % loglevel)

logging.basicConfig(format='%(asctime)s %(message)s', datefmt='%m/%d/%Y %I:%M:%S %p', level=numeric_level)

log = logging
# Out:
# 04/29/2018 11:41:13 PM backend module://ipykernel.pylab.backend_inline version unknown

# %%
## Loading and converting Data
YEARS = range(1, 6)
# Load Data
log.info("Loading data ...")
FILENAMES = 'data/{year}year.arff'
data = {i: arff.loadarff(FILENAMES.format(year=i)) for i in YEARS}
dfs = dict(list(starmap(lambda k, v: (k, pd.DataFrame(v[0])), data.items())))
log.info("Data loaded !")
# Out:
# 04/29/2018 11:41:13 PM Loading data ...
# 04/29/2018 11:41:15 PM Data loaded !

# %% [markdown]
# Les ensembles de données pour chaque année sont composés de 64 colonnes, 1 pour chaque caractéristique et 1 colonne cible ("class") qui montre l'état de faillite de l'entreprise.
# #### Note
# Dans ce qui suit, nous illustrerons nos résultats à l'aide de l'exemple de la première année, mais ces résultats restent valables pour les autres années.

# %%
# Attributes of the 1st year
# They are the same for the other YEARS
dfs[1].columns
# Out:
# Index(['Attr1', 'Attr2', 'Attr3', 'Attr4', 'Attr5', 'Attr6', 'Attr7', 'Attr8',
#        'Attr9', 'Attr10', 'Attr11', 'Attr12', 'Attr13', 'Attr14', 'Attr15',
#        'Attr16', 'Attr17', 'Attr18', 'Attr19', 'Attr20', 'Attr21', 'Attr22',
#        'Attr23', 'Attr24', 'Attr25', 'Attr26', 'Attr27', 'Attr28', 'Attr29',
#        'Attr30', 'Attr31', 'Attr32', 'Attr33', 'Attr34', 'Attr35', 'Attr36',
#        'Attr37', 'Attr38', 'Attr39', 'Attr40', 'Attr41', 'Attr42', 'Attr43',
#        'Attr44', 'Attr45', 'Attr46', 'Attr47', 'Attr48', 'Attr49', 'Attr50',
#        'Attr51', 'Attr52', 'Attr53', 'Attr54', 'Attr55', 'Attr56', 'Attr57',
#        'Attr58', 'Attr59', 'Attr60', 'Attr61', 'Attr62', 'Attr63', 'Attr64',
#        'class'],
#       dtype='object')

# %% [markdown]
# La description des données nous montre que certaines colonnes ont des valeurs Nan, ainsi que les données de la même colonne sont très dispersées (min, max, écart moyen).

# %%
dfs[1].describe()
# Out:
#              Attr1        Attr2        Attr3        Attr4         Attr5  \
# count  7024.000000  7024.000000  7024.000000  6997.000000  7.019000e+03
# mean      0.034660     0.560215     0.119969     2.629143 -2.631672e+02
# std       4.565504     5.350084     5.275459    13.257356  3.707460e+04
# min    -256.890000   -72.162000  -440.500000     0.000000 -2.722100e+06
# 25%       0.021182     0.296678     0.026968     1.063100 -4.449800e+01
# 50%       0.075802     0.482960     0.181275     1.502000 -5.373900e+00
# 75%       0.160268     0.680233     0.362548     2.460700  3.777050e+01
# max      94.280000   441.500000     1.000000  1017.800000  9.909000e+05
#
#              Attr6        Attr7        Attr8        Attr9       Attr10  \
# count  7024.000000  7024.000000  7002.000000  7026.000000  7024.000000
# mean      0.059712     0.313876     2.623996     5.552855     1.825832
# std       6.051113     8.353274    18.708327   101.995448    33.836452
# min    -397.890000  -189.560000  -141.410000     0.000005  -440.550000
# 25%       0.000000     0.028023     0.445710     1.037225     0.300785
# 50%       0.000000     0.090109     1.015100     1.205750     0.492235
# 75%       0.146660     0.188667     2.267675     2.132975     0.675677
# max     303.670000   453.770000  1452.200000  3876.100000  1099.500000
#
#            ...              Attr55        Attr56       Attr57        Attr58  \
# count      ...        7.027000e+03  7.027000e+03  7026.000000  7.027000e+03
# mean       ...        8.855693e+03 -1.577367e+02     0.193243  1.587409e+02
# std        ...        7.247527e+04  1.322125e+04     4.344046  1.322124e+04
# min        ...       -8.004700e+05 -1.108300e+06  -315.370000 -4.194000e-03
# 25%        ...        9.712000e+01  2.031450e-02     0.056772  8.647650e-01
# 50%        ...        1.604800e+03  6.338200e-02     0.175745  9.388100e-01
# 75%        ...        5.955900e+03  1.376950e-01     0.351922  9.820150e-01
# max        ...        4.398400e+06  1.000000e+00   126.670000  1.108300e+06
#
#             Attr59        Attr60        Attr61        Attr62       Attr63  \
# count  7026.000000  6.892000e+03   7005.000000  7.027000e+03  6997.000000
# mean      0.277829  4.328830e+02     15.642228  4.763202e+03     8.126852
# std       6.339149  2.612802e+04    261.554534  3.107835e+05    19.996419
# min    -327.970000  4.700000e-05      0.000016  0.000000e+00     0.000015
# 25%       0.000000  5.923950e+00      4.829000  4.322250e+01     3.425400
# 50%       0.028438  1.004050e+01      7.033700  6.850900e+01     5.303200
# 75%       0.273867  2.013900e+01     10.703000  1.063350e+02     8.357900
# max     119.580000  2.137800e+06  21110.000000  2.501600e+07  1042.200000
#
#               Attr64
# count    6993.000000
# mean      208.731950
# std      5140.708804
# min         0.000010
# 25%         2.538600
# 50%         4.637700
# 75%         9.782200
# max    294770.000000
#
# [8 rows x 64 columns]

# %% [markdown]
# Les classes sont au format binaire, d'où la nécessité de les convertir en entiers.

# %%
dfs[1]['class'].tail()
# Out:
# 7022    b'1'
# 7023    b'1'
# 7024    b'1'
# 7025    b'1'
# 7026    b'1'
# Name: class, dtype: object

# %% [markdown]
# Le pourcentage d'entreprises qui ont fait faillite étant très faible, nous pouvons facilement atteindre de très bonnes performances qui peuvent dépasser 95% même si notre algorithme  prédit  qu'il n'y a pas de faillite, d'où la nécessité de bien définir le mode d'évaluation de l'algorithme.

# %%
for i in YEARS:
    dfs[i]["class"] = dfs[i]["class"].apply(lambda x: int(x.decode("utf8")))
    print("Year {}: {}% of polish firms bunckrpted".format(i, '%.2f' % (dfs[i]["class"].sum() / dfs[i]["class"].count() * 100)))
# Out:
# Year 1: 3.86% of polish firms bunckrpted
# Year 2: 3.93% of polish firms bunckrpted
# Year 3: 4.71% of polish firms bunckrpted
# Year 4: 5.26% of polish firms bunckrpted
# Year 5: 6.94% of polish firms bunckrpted

# %% [markdown]
# Des graphique montrant les valeurs aberrantes de certains colonnes.

# %%
# Graph showing the outliers of some features
dfs[1].boxplot(column=["Attr1"])
# Out:
# 04/29/2018 11:41:16 PM findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('C:\\Users\\SalahEddine\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000

# %%
dfs[1].boxplot(column=["Attr5", "Attr31", "Attr55", "Attr56", "Attr59"])

# %%
from tabulate import tabulate
from pprint import pprint

nan_counter=[]
for attr in dfs[1].columns[:-1]:
    nan_counter.append(dfs[1][attr].isnull().sum())

nan_counter = np.array(nan_counter)
table = ["NAN values in a columns"] + [nan_counter.min(), nan_counter.max(), nan_counter.mean(), nan_counter.std()]
print(tabulate([table], headers=['min', 'max', 'mean', "std"]))

unique, counts = np.unique(nan_counter, return_counts=True)
unique = [str(x) for x in unique]
plt.figure(figsize=(18, 4))
plt.bar(unique, height= counts)
plt.title("Histogram of NaNs")
# Out:
#                            min    max     mean      std
# -----------------------  -----  -----  -------  -------
# NAN values in a columns      0   2740  91.1719  390.933
# Text(0.5,1,'Histogram of NaNs')
# 04/29/2018 11:41:17 PM findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('C:\\Users\\SalahEddine\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000

# %%
plt.figure(figsize=(18, 4))
plt.scatter(range(1,65), y=nan_counter, color = 'navy')
plt.title("NaNs per feature")
# Out:
# Text(0.5,1,'NaNs per feature')

# %% [markdown]
# ## Nettoyage et prétraitement des données

# %% [markdown]
# After visualizing and studying the distribution of the features, we have come to the conclusion:
#
# - Presence of NaNs in the Dataset which require some replacement
#     - We have replaced nans with the median since we have a lot of outliers
# - presence of binary data types
#     - perform a casting on the data
# - Scales varies a lot between features thus the normalization
#     - We normalize with the formula: $ X^* = \frac{X - \bar{X}}{\max X - \min X }$
# - Presence of outliers
#     - Remove outliers (not bunckrupt) that verify the following $|Y| > \alpha|\bar{Y}|$ given that $\alpha \sim 70 \text{(empiric)}$
#
# We will created a new cleansed dataset.

# %%
def process(year, df):
    # Fill NAN values with median
    def fillna_median(c):
        return c.fillna(c.median())

    # Normalizing data 
    def normalize(series):
        if series.name != "class":
            return (series - series.mean())/ (series.max() - series.min())
        else:
            return series
    
    def f(p):
        def outliers(series):
            if series.name != "class":
                mean = np.abs(series.mean())
                series[np.abs(series) > p * mean] = np.nan
                return series
            else:
                return series
        return outliers


    log.info("year {}: Filling NaNs with median ...".format(year))
    df = df.apply(fillna_median, axis=0)
    log.info("year {}: NaNs filled !".format(year))

    log.info("year {}: Dropping outliers data ...".format(year))
    df = df.apply(f(80), axis=0)
    df = df.dropna()
    log.info("year {}: Outliers dropped !".format(year))
    
    log.info("year {}: Normalizing data ...".format(year))
    df = df.apply(normalize, axis=0)
    log.info("year {}: Data normalized !".format(year))


    
    return df

log.info("Processing and saving cleaned datasets...")
pp_dfs = {}
for key, value in dfs.items():
    pp_dfs[key] = process(key, value)
    # Save File
    pp_dfs[key].to_csv('data/cleaned-dataset-{}.csv'.format(key), index=False)

log.info("Data processed and saved!")
# Out:
# 04/30/2018 12:18:08 AM Processing and saving cleaned datasets...
# 04/30/2018 12:18:08 AM year 1: Filling NaNs with median ...
# 04/30/2018 12:18:08 AM year 1: NaNs filled !
# 04/30/2018 12:18:08 AM year 1: Dropping outliers data ...
# C:\Users\SalahEddine\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 04/30/2018 12:18:11 AM year 1: Outliers dropped !
# 04/30/2018 12:18:11 AM year 1: Normalizing data ...
# 04/30/2018 12:18:11 AM year 1: Data normalized !
# 04/30/2018 12:18:12 AM year 2: Filling NaNs with median ...
# 04/30/2018 12:18:12 AM year 2: NaNs filled !
# 04/30/2018 12:18:12 AM year 2: Dropping outliers data ...
# 04/30/2018 12:18:15 AM year 2: Outliers dropped !
# 04/30/2018 12:18:15 AM year 2: Normalizing data ...
# 04/30/2018 12:18:15 AM year 2: Data normalized !
# 04/30/2018 12:18:17 AM year 3: Filling NaNs with median ...
# 04/30/2018 12:18:17 AM year 3: NaNs filled !
# 04/30/2018 12:18:17 AM year 3: Dropping outliers data ...
# 04/30/2018 12:18:20 AM year 3: Outliers dropped !
# 04/30/2018 12:18:20 AM year 3: Normalizing data ...
# 04/30/2018 12:18:20 AM year 3: Data normalized !
# 04/30/2018 12:18:22 AM year 4: Filling NaNs with median ...
# 04/30/2018 12:18:22 AM year 4: NaNs filled !
# 04/30/2018 12:18:22 AM year 4: Dropping outliers data ...
# 04/30/2018 12:18:26 AM year 4: Outliers dropped !
# 04/30/2018 12:18:26 AM year 4: Normalizing data ...
# 04/30/2018 12:18:26 AM year 4: Data normalized !
# 04/30/2018 12:18:27 AM year 5: Filling NaNs with median ...
# 04/30/2018 12:18:28 AM year 5: NaNs filled !
# 04/30/2018 12:18:28 AM year 5: Dropping outliers data ...
# 04/30/2018 12:18:31 AM year 5: Outliers dropped !
# 04/30/2018 12:18:31 AM year 5: Normalizing data ...
# 04/30/2018 12:18:32 AM year 5: Data normalized !
# 04/30/2018 12:18:33 AM Data processed and saved!

# %% [markdown]
# ## Feature engineering

# %%
[pp_dfs[x].shape for x in pp_dfs]
# Out:
# [(6847, 65), (9579, 65), (9103, 65), (7530, 65), (5319, 65)]

# %%
from itertools import cycle

def plot_2D(data,target,target_names, attr1, attr2):
    colors = cycle('rgb')
    target_ids = range(len(target_names))
    plt.figure()
    for i,c,label in zip(target_ids,colors, target_names):
        a = plt.scatter(data[target==i][attr1], data[target==i][attr2],c=c,label=label)
    plt.legend()
#     plt.ylim((0, 0.0005))
    plt.show()
    return a

a = plot_2D(pp_dfs[1],pp_dfs[1]["class"],("Survived","Bunkrupted"), "Attr8", "Attr7")

# %%
# class pas tres correle, maybe kernel trick
pp_dfs[1].corr()
# Out:
#            Attr1     Attr2     Attr3     Attr4     Attr5     Attr6     Attr7  \
# Attr1   1.000000 -0.155932  0.159913  0.003706  0.008365  0.129868  0.422068
# Attr2  -0.155932  1.000000 -0.985782 -0.009683 -0.052235 -0.772227 -0.193355
# Attr3   0.159913 -0.985782  1.000000  0.011213  0.052916  0.781194  0.087042
# Attr4   0.003706 -0.009683  0.011213  1.000000 -0.000896  0.002380 -0.000554
# Attr5   0.008365 -0.052235  0.052916 -0.000896  1.000000  0.040982  0.004789
# Attr6   0.129868 -0.772227  0.781194  0.002380  0.040982  1.000000  0.249863
# Attr7   0.422068 -0.193355  0.087042 -0.000554  0.004789  0.249863  1.000000
# Attr8   0.003949 -0.008582  0.007718  0.191226  0.002102  0.004007 -0.019325
# Attr9  -0.561938 -0.073338 -0.000664 -0.003428  0.003074  0.081818  0.365900
# Attr10 -0.349011 -0.221383  0.155591 -0.002020  0.008558  0.307387  0.516819
# Attr11  0.397935 -0.103102 -0.001075 -0.000911  0.000173  0.178282  0.994388
# Attr12  0.010529 -0.010366  0.009140  0.539544 -0.000053  0.005068  0.003437
# Attr13  0.000667 -0.002873  0.003570  0.084248 -0.000041  0.002844 -0.000027
# Attr14  0.422068 -0.193355  0.087042 -0.000554  0.004789  0.249863  1.000000
# Attr15  0.000146  0.000332  0.000969 -0.002365 -0.446782 -0.000052 -0.000618
# Attr16  0.009575 -0.007214  0.008773  0.156821  0.001613  0.005184 -0.019793
# Attr17  0.003853 -0.010576  0.007514  0.186995  0.002057  0.004045 -0.001764
# Attr18  0.422068 -0.193355  0.087042 -0.000554  0.004789  0.249863  1.000000
# Attr19  0.003725 -0.017806  0.018683  0.444001 -0.000607  0.015323  0.001739
# Attr20 -0.000068  0.000656 -0.000018 -0.001200  0.000094 -0.000108 -0.000421
# Attr21  0.000042 -0.000859  0.001064  0.005061  0.000148 -0.000154 -0.000596
# Attr22  0.463856 -0.106255 -0.001171 -0.000755  0.000130  0.021722  0.957465
# Attr23  0.003743 -0.018350  0.019264  0.394368 -0.000352  0.015581  0.001627
# Attr24  0.265102 -0.176272  0.054324 -0.000545  0.003042  0.254492  0.972030
# Attr25 -0.646808 -0.195783  0.189622 -0.001158  0.010262  0.191663 -0.007198
# Attr26  0.006725 -0.006977  0.005630  0.127919  0.001156  0.003904 -0.000508
# Attr27  0.008462 -0.004993  0.002838  0.016750  0.000357 -0.000484  0.015347
# Attr28  0.004583 -0.004186  0.010698  0.017081  0.000500  0.000805  0.001059
# Attr29  0.087484 -0.050353  0.053899 -0.002979 -0.002679  0.011512 -0.107858
# Attr30 -0.000417  0.002883 -0.002308  0.002765 -0.000961 -0.001878 -0.000658
# ...          ...       ...       ...       ...       ...       ...       ...
# Attr36 -0.561856 -0.073245 -0.000753 -0.003709  0.000583  0.082073  0.365947
# Attr37  0.000135 -0.001268  0.000359 -0.000386  0.000146  0.000400 -0.000972
# Attr38 -0.349053 -0.221320  0.155586 -0.002138  0.008621  0.307359  0.516862
# Attr39  0.000634  0.001318 -0.000625 -0.000056  0.000258  0.000843  0.000218
# Attr40  0.001726 -0.004408  0.005330  0.970126 -0.002976  0.000688 -0.002028
# Attr41 -0.005408  0.039239 -0.038770 -0.002633 -0.251103 -0.031066 -0.004402
# Attr42  0.000724  0.001164 -0.000468 -0.014571  0.000321  0.000987  0.000273
# Attr43 -0.000066  0.000668 -0.000044 -0.000976 -0.000228 -0.000129 -0.000450
# Attr44 -0.000066  0.000673 -0.000053 -0.000898 -0.000340 -0.000136 -0.000460
# Attr45  0.001054 -0.002773  0.003255  0.002898  0.000150  0.002346  0.000944
# Attr46  0.003023 -0.007460  0.008819  0.988126 -0.001566  0.001745 -0.001756
# Attr47  0.000047 -0.000522  0.001645  0.000067  0.014906  0.001467  0.001112
# Attr48  0.490984 -0.100451 -0.001388  0.000255  0.000012 -0.043258  0.897414
# Attr49  0.000253 -0.000514 -0.000095 -0.002250 -0.000032  0.000392  0.000603
# Attr50  0.008591 -0.020581  0.022844  0.400062  0.005024  0.006289 -0.002514
# Attr51 -0.158139  0.986503 -0.999136 -0.009172 -0.053359 -0.782377 -0.088994
# Attr52 -0.100935  0.628819 -0.637066  0.017217 -0.201286 -0.499245 -0.057259
# Attr53 -0.008004 -0.012227 -0.000646 -0.003177  0.000246  0.065437  0.183460
# Attr54 -0.007987 -0.012178 -0.000658 -0.003199  0.000247  0.065094  0.182812
# Attr55  0.002983 -0.009708  0.010826  0.021748  0.002827  0.004542 -0.002078
# Attr56  0.000061 -0.000655  0.000019  0.001193 -0.000091  0.000118  0.000432
# Attr57  0.004398 -0.000743  0.002130  0.001962  0.000274  0.000411  0.000828
# Attr58 -0.000061  0.000656 -0.000019 -0.001193  0.000091 -0.000118 -0.000432
# Attr59  0.000287  0.000979 -0.001116 -0.005650  0.004470 -0.000066 -0.001245
# Attr60 -0.000390 -0.000025 -0.000324 -0.001282  0.000126 -0.000172 -0.000775
# Attr61  0.002033 -0.002262 -0.001286 -0.003319 -0.000168  0.000664  0.019131
# Attr62 -0.000848  0.005456 -0.005054 -0.001612 -0.002224 -0.003916 -0.000973
# Attr63  0.010422 -0.017384  0.016144  0.259545  0.005421  0.005844  0.003869
# Attr64 -0.040552 -0.019051 -0.000895 -0.003553  0.000544  0.047249  0.192839
# class  -0.010644  0.065151 -0.065103  0.008143 -0.002015 -0.052310 -0.012164
#
#            Attr8     Attr9    Attr10    ...       Attr56    Attr57    Attr58  \
# Attr1   0.003949 -0.561938 -0.349011    ...     0.000061  0.004398 -0.000061
# Attr2  -0.008582 -0.073338 -0.221383    ...    -0.000655 -0.000743  0.000656
# Attr3   0.007718 -0.000664  0.155591    ...     0.000019  0.002130 -0.000019
# Attr4   0.191226 -0.003428 -0.002020    ...     0.001193  0.001962 -0.001193
# Attr5   0.002102  0.003074  0.008558    ...    -0.000091  0.000274  0.000091
# Attr6   0.004007  0.081818  0.307387    ...     0.000118  0.000411 -0.000118
# Attr7  -0.019325  0.365900  0.516819    ...     0.000432  0.000828 -0.000432
# Attr8   1.000000 -0.015843 -0.016862    ...     0.001565  0.001225 -0.001565
# Attr9  -0.015843  1.000000  0.912149    ...     0.000650 -0.001834 -0.000650
# Attr10 -0.016862  0.912149  1.000000    ...     0.000593 -0.002167 -0.000593
# Attr11 -0.020055  0.383265  0.526173    ...     0.000472  0.000689 -0.000472
# Attr12  0.787000 -0.002471 -0.001418    ...     0.001726  0.010969 -0.001726
# Attr13 -0.000570 -0.000687 -0.000052    ...    -0.994566 -0.000244  0.994566
# Attr14 -0.019325  0.365900  0.516819    ...     0.000432  0.000828 -0.000432
# Attr15 -0.002174 -0.000737 -0.000948    ...    -0.000362  0.000854  0.000362
# Attr16  0.911977 -0.017839 -0.019527    ...     0.001680  0.009384 -0.001680
# Attr17  0.995457 -0.003898 -0.002602    ...     0.001579  0.001172 -0.001579
# Attr18 -0.019325  0.365900  0.516819    ...     0.000432  0.000828 -0.000432
# Attr19  0.003717 -0.000724  0.002310    ...    -0.839320  0.000105  0.839320
# Attr20 -0.001576 -0.000632 -0.000564    ...    -0.999996 -0.000327  0.999996
# Attr21  0.004578 -0.000852 -0.000677    ...     0.000232  0.010273 -0.000232
# Attr22 -0.020243  0.305501  0.416178    ...     0.000396  0.000803 -0.000396
# Attr23  0.003470 -0.000766  0.002305    ...    -0.864865  0.000127  0.864865
# Attr24 -0.016812  0.451216  0.551618    ...     0.000466  0.000393 -0.000466
# Attr25 -0.009043  0.829646  0.839438    ...     0.000516 -0.002011 -0.000516
# Attr26  0.941083 -0.003314 -0.003254    ...     0.001148  0.006550 -0.001148
# Attr27  0.011175  0.006670  0.005499    ...     0.000435  0.009510 -0.000435
# Attr28  0.004968 -0.005332 -0.002744    ...     0.001081  0.008861 -0.001081
# Attr29  0.016965 -0.198328 -0.198485    ...     0.023280 -0.025012 -0.023280
# Attr30 -0.001642 -0.000700 -0.000984    ...    -0.998201 -0.000362  0.998201
# ...          ...       ...       ...    ...          ...       ...       ...
# Attr36 -0.016484  0.999916  0.912118    ...     0.000691 -0.001852 -0.000691
# Attr37  0.001621 -0.001124 -0.000900    ...     0.000256 -0.000603 -0.000256
# Attr38 -0.017126  0.912139  0.999990    ...     0.000452 -0.002159 -0.000452
# Attr39 -0.000060 -0.000435 -0.000522    ...    -0.950356  0.000095  0.950356
# Attr40  0.123307 -0.003753 -0.003902    ...     0.000698  0.000484 -0.000698
# Attr41 -0.003013 -0.001744 -0.007991    ...     0.000175 -0.003652 -0.000175
# Attr42 -0.000160 -0.000430 -0.000477    ...    -0.950249  0.000142  0.950249
# Attr43 -0.001566 -0.000674 -0.000611    ...    -0.999559 -0.000342  0.999559
# Attr44 -0.001562 -0.000688 -0.000627    ...    -0.999238 -0.000347  0.999238
# Attr45  0.002774  0.000426  0.000832    ...    -0.000116  0.001526  0.000116
# Attr46  0.164570 -0.004257 -0.004037    ...     0.000798  0.001698 -0.000798
# Attr47 -0.001678  0.001733  0.002368    ...     0.000842 -0.000622 -0.000842
# Attr48 -0.018426  0.244780  0.310689    ...     0.000302  0.001187 -0.000302
# Attr49  0.001863  0.000704  0.000614    ...     0.996864  0.000428 -0.996864
# Attr50  0.481935 -0.007693 -0.005133    ...     0.003500  0.004205 -0.003500
# Attr51 -0.009114 -0.003173 -0.159654    ...     0.000225 -0.001311 -0.000224
# Attr52 -0.002538 -0.002247 -0.102274    ...     0.000707 -0.001450 -0.000707
# Attr53 -0.008763  0.194293  0.305184    ...     0.000421 -0.001506 -0.000421
# Attr54 -0.008750  0.193583  0.304074    ...     0.000419 -0.001505 -0.000419
# Attr55  0.019515 -0.005161 -0.003651    ...     0.001454  0.002403 -0.001455
# Attr56  0.001565  0.000650  0.000593    ...     1.000000  0.000314 -1.000000
# Attr57  0.001225 -0.001834 -0.002167    ...     0.000314  1.000000 -0.000314
# Attr58 -0.001565 -0.000650 -0.000593    ...    -1.000000 -0.000314  1.000000
# Attr59 -0.004907 -0.001744 -0.001964    ...    -0.005743 -0.268691  0.005743
# Attr60 -0.000957 -0.000530 -0.000665    ...     0.000196 -0.001218 -0.000196
# Attr61  0.000431  0.032698  0.046001    ...     0.000714  0.001105 -0.000714
# Attr62 -0.001833 -0.000829 -0.001491    ...    -0.960360 -0.000528  0.960360
# Attr63  0.483250 -0.000186  0.001196    ...     0.004856  0.009699 -0.004856
# Attr64 -0.010895  0.255477  0.318342    ...     0.000484 -0.001659 -0.000484
# class  -0.000089 -0.007060 -0.018705    ...     0.002390 -0.060031 -0.002389
#
#           Attr59    Attr60    Attr61    Attr62    Attr63    Attr64     class
# Attr1   0.000287 -0.000390  0.002033 -0.000848  0.010422 -0.040552 -0.010644
# Attr2   0.000979 -0.000025 -0.002262  0.005456 -0.017384 -0.019051  0.065151
# Attr3  -0.001116 -0.000324 -0.001286 -0.005054  0.016144 -0.000895 -0.065103
# Attr4  -0.005650 -0.001282 -0.003319 -0.001612  0.259545 -0.003553  0.008143
# Attr5   0.004470  0.000126 -0.000168 -0.002224  0.005421  0.000544 -0.002015
# Attr6  -0.000066 -0.000172  0.000664 -0.003916  0.005844  0.047249 -0.052310
# Attr7  -0.001245 -0.000775  0.019131 -0.000973  0.003869  0.192839 -0.012164
# Attr8  -0.004907 -0.000957  0.000431 -0.001833  0.483250 -0.010895 -0.000089
# Attr9  -0.001744 -0.000530  0.032698 -0.000829 -0.000186  0.255477 -0.007060
# Attr10 -0.001964 -0.000665  0.046001 -0.001491  0.001196  0.318342 -0.018705
# Attr11 -0.001362 -0.000805  0.019409 -0.000603  0.002954  0.200537 -0.006608
# Attr12 -0.004061 -0.002161  0.049608 -0.002202  0.577068  0.012950 -0.017242
# Attr13  0.005716 -0.000218 -0.000725  0.942309 -0.004988 -0.000496 -0.002862
# Attr14 -0.001245 -0.000775  0.019131 -0.000973  0.003869  0.192839 -0.012164
# Attr15  0.003215 -0.001158 -0.000616  0.000812 -0.003275 -0.000471  0.008643
# Attr16 -0.005010 -0.001914  0.002077 -0.002211  0.598452 -0.011550 -0.013738
# Attr17 -0.004932 -0.001002  0.000352 -0.001856  0.477073 -0.003621 -0.000122
# Attr18 -0.001245 -0.000775  0.019131 -0.000973  0.003869  0.192839 -0.012164
# Attr19  0.004824 -0.000289 -0.000759  0.738362 -0.004829 -0.000527 -0.004445
# Attr20  0.005743 -0.000205 -0.000706  0.961081 -0.004923 -0.000457 -0.002395
# Attr21 -0.033050 -0.000291  0.000076 -0.000291  0.016741 -0.000716 -0.003888
# Attr22 -0.001061 -0.000721  0.001874 -0.000507  0.001277  0.157199 -0.005377
# Attr23  0.005007 -0.000270 -0.000755  0.759430 -0.004558 -0.000572 -0.004350
# Attr24 -0.001268 -0.000707  0.002702 -0.000872  0.000706  0.195145 -0.010704
# Attr25 -0.001565 -0.000483  0.028604 -0.001536 -0.000143  0.229194 -0.019279
# Attr26 -0.003485 -0.001321  0.001751 -0.001515  0.514371 -0.003210 -0.010425
# Attr27 -0.001466 -0.000104  0.001109 -0.000555  0.043967  0.000583 -0.006537
# Attr28 -0.003135 -0.000878 -0.208106 -0.001463 -0.015238 -0.051673 -0.013712
# Attr29  0.023431 -0.014174 -0.054248 -0.015799 -0.127713 -0.120381 -0.041740
# Attr30  0.005675 -0.000209 -0.000766  0.975288 -0.005223 -0.000522 -0.002392
# ...          ...       ...       ...       ...       ...       ...       ...
# Attr36 -0.001990 -0.000563  0.032832 -0.000880  0.000281  0.255402 -0.006866
# Attr37 -0.000931 -0.000330 -0.000881 -0.000321 -0.002367 -0.001153 -0.003043
# Attr38 -0.001690 -0.000703  0.046955 -0.001364  0.001095  0.318730 -0.018667
# Attr39  0.005712 -0.000219 -0.000459  0.826316 -0.002699 -0.000334 -0.001853
# Attr40 -0.002435 -0.000092 -0.093536 -0.000674  0.102014 -0.034106  0.010365
# Attr41  0.012559 -0.000787 -0.001537  0.000200 -0.007332 -0.001653 -0.005944
# Attr42  0.005702 -0.000209 -0.000453  0.826233 -0.002602 -0.000325 -0.001840
# Attr43  0.005710 -0.000204 -0.000742  0.968191 -0.005052 -0.000499 -0.002470
# Attr44  0.005697 -0.000204 -0.000755  0.970483 -0.005096 -0.000514 -0.002495
# Attr45  0.000444 -0.981920  0.000428  0.000120  0.004500  0.000409  0.002696
# Attr46 -0.003479 -0.000414 -0.093450 -0.001025  0.183275 -0.034124  0.005647
# Attr47  0.000082 -0.001230  0.005771 -0.000960 -0.005662  0.003741 -0.006834
# Attr48 -0.000755 -0.000608 -0.066196 -0.000359 -0.005658  0.062378 -0.003163
# Attr49 -0.005668  0.000189  0.000745 -0.979281  0.005367  0.000504  0.002517
# Attr50 -0.012329 -0.001711 -0.003061 -0.004373  0.651746 -0.006393  0.022087
# Attr51 -0.000709  0.000232 -0.000956  0.004736 -0.015872 -0.002737  0.064747
# Attr52 -0.000092 -0.000513 -0.000898  0.014010 -0.014550 -0.002550  0.034058
# Attr53 -0.001498 -0.000564  0.342867 -0.000540  0.051033  0.973310 -0.007026
# Attr54 -0.001496 -0.000566  0.353914 -0.000538  0.053012  0.973437 -0.007025
# Attr55 -0.004638 -0.001463 -0.003857 -0.005743  0.010717 -0.004441 -0.022040
# Attr56 -0.005743  0.000196  0.000714 -0.960360  0.004856  0.000484  0.002390
# Attr57 -0.268691 -0.001218  0.001105 -0.000528  0.009699 -0.001659 -0.060031
# Attr58  0.005743 -0.000196 -0.000714  0.960360 -0.004856 -0.000484 -0.002389
# Attr59  1.000000 -0.000666 -0.001562  0.005322 -0.011148 -0.001677  0.002222
# Attr60 -0.000666  1.000000 -0.000572 -0.000245 -0.001538 -0.000573 -0.002525
# Attr61 -0.001562 -0.000572  1.000000 -0.000906  0.175147  0.359634 -0.002513
# Attr62  0.005322 -0.000245 -0.000906  1.000000 -0.006175 -0.000620 -0.002679
# Attr63 -0.011148 -0.001538  0.175147 -0.006175  1.000000  0.052459  0.005050
# Attr64 -0.001677 -0.000573  0.359634 -0.000620  0.052459  1.000000 -0.007258
# class   0.002222 -0.002525 -0.002513 -0.002679  0.005050 -0.007258  1.000000
#
# [65 rows x 65 columns]

# %% [markdown]
# Thus the necessity of using ACP Analysis to reduce the dimensionality of the problem.

# %%
logdb = pd.concat([np.log10(pp_dfs[1].ix[:,2:9])], 
               axis=1).replace([np.inf, - np.inf],
                               np.nan).dropna()
g = sns.PairGrid(logdb)
g.map_upper(sns.regplot) 
g.map_lower(plt.scatter)
g.map_diag(plt.hist)  
plt.show()
# Out:
# C:\Users\SalahEddine\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\Users\SalahEddine\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
pp_dfs[1].ix[:,2:9].corr().round(2)

# %% [markdown]
# We have plotted the first 9 attributs just for illustration

# %%
from sklearn.preprocessing import StandardScaler
StandardScaler().fit_transform(pp_dfs[1]).shape
# Out:
# (6847, 65)

# %%
db = pp_dfs[1]

S = np.diag(1/db.ix[:,:-1].std())
mu = np.matrix(db.ix[:,:-1].mean())
U = np.matrix([np.ones(db.ix[:,:-1].shape[0])])
X = pd.DataFrame((db.ix[:,:-1] - U.T.dot(mu)).dot(S).values,columns = db.columns[:-1])

Var_X = X.cov() # obtenir la matrice variance covariance
val_propres,vec_propres = np.linalg.eig(Var_X)
ordre = val_propres.argsort()[::-1]
val_propres = val_propres[ordre]
vec_propres = vec_propres[:,ordre]

row = ["Comp." + str(i+1) for i in range(64)]
col = ["Std deviation","Prop.of Variance(%)","Cumulative Prop.(%)"]
tot = sum(val_propres)
res_1 = pd.DataFrame([[i**0.5,np.round(i*100 /tot,2),np.round(j*100/tot,2)]
                      for i,j in zip(val_propres,np.cumsum(val_propres))],
                        columns= col,index = row)
res_2 = pd.DataFrame(vec_propres,columns = row,
                                 index = db.columns[:-1])

plt.clf()
plt.subplot(211)
plt.axis([0.5,20.5,0,105])
plt.bar(range(1,65), res_1.ix[:,1], alpha=0.5,
             align='center',
            label="Proportion of Variance(%)")
plt.step(range(1,65),res_1.ix[:,2], where='mid',
             label="Cumulative Proportion(%)")
plt.ylabel("Variance expliquée")
plt.xlabel("Composant principal")
plt.legend(loc='best')
plt.subplot(212)
plt.axis([0.5,20.5,0,40])
plt.plot(range(1,65),res_1.ix[:,1], linestyle='--',
              marker='o', color='black')
plt.ylabel("Valeur propres")
plt.xlabel("Composant principal")
plt.title("Scree plot")
plt.tight_layout()
# Out:
# C:\Users\SalahEddine\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\SalahEddine\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
from sklearn.decomposition import PCA as princomp
cpa = princomp(n_components=7)
Z = cpa.fit_transform(pp_dfs[1])
# TODO conctaenate with class and rename columns 
Zdf = pd.DataFrame(Z)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint
from sklearn import linear_model, ensemble, svm, neural_network, neighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score, GridSearchCV
import xgboost
import pickle
import seaborn as sns
# Out:
# C:\Users\SalahEddine\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
class Classifier:
    def __init__(self, train_df, test_df=None, model=None, **kwargs):
        self.df = train_df
        self.tdf = test_df
        if type(model) == type('') or not model:
            if (model == "linear") or model == "l":
                self.model = linear_model.SGDClassifier(**kwargs)
            elif (model == "random_forst") or model == "rf":
                self.model = ensemble.RandomForestClassifier(**kwargs)
            elif model == "svm":
                self.model = svm.SVC(**kwargs)
            elif model == "nn":
                self.model = neural_network.MLPClassifier(**kwargs)
            elif model == "knn":
                self.model = neighbors.KNeighborsClassifier(**kwargs)
            elif model == "xgb":
                self.model = xgboost.XGBClassifier(**kwargs)
            elif model == 'gb':
                params = {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 2,
                          'learning_rate': 0.01}
                self.model = ensemble.GradientBoostingClassifier(**params)
            self.fit = True
        else:
            self.fit = False
            self.model = model

        
    def cross_validate(self, test_size=0.2, fit=True):
        X = self.df.drop(labels=(['class']), axis=1).as_matrix()
        y = self.df['class'].as_matrix()
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=0)
        if fit and self.fit:
            self.model.fit(X_train, y_train)
            pickle.dump(self.model, open("model.bin", 'wb'))
            self.fit = False
        y_pred = self.model.predict(X_test)
        return accuracy_score(y_test, y_pred)

    
    def predict(self):
        X = self.df.drop(labels=(['class']), axis=1).as_matrix()
        y = self.df['class'].as_matrix()
        rX = self.tdf.drop(labels=['class'], axis=1).as_matrix()
        if self.fit:
            self.model.fit(X, y)
            pickle.dump(self.model, open("model.bin", 'wb'))
        y_pred = self.model.predict(rX)
        return y_pred

# %%
c = Classifier(train_df=Zdf, test_df=Zdf, model="l")
c.cross_validate()
sum(c.predict())
c.tdf['class'].as_matrix().sum(), accuracy_score(c.predict(), c.tdf['class'].as_matrix()), sum(c.predict())
cross_val_score(c.model, c.tdf.drop(labels=['class'], axis=1), c.tdf['class'].as_matrix())
parameters = {'n_estimators':(500, 200)}
A = GridSearchCV(cv=3, estimator=c.model, n_jobs=1, param_grid=parameters, scoring='accuracy')
X = dfs[1].drop(labels=(['class']), axis=1).as_matrix()
y = dfs[1]['class'].as_matrix()
A.fit(X, y)
A.cv_results_
# Out:
# C:\Users\SalahEddine\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-4308987acb73> in <module>()
#       1 c = Classifier(train_df=Zdf, test_df=Zdf, model="l")
# ----> 2 c.cross_validate()
#       3 sum(c.predict())
#       4 c.tdf['class'].as_matrix().sum(), accuracy_score(c.predict(), c.tdf['class'].as_matrix()), sum(c.predict())
#       5 cross_val_score(c.model, c.tdf.drop(labels=['class'], axis=1), c.tdf['class'].as_matrix())
#
# <ipython-input-70-732bbf1526d4> in cross_validate(self, test_size, fit)
#      27
#      28     def cross_validate(self, test_size=0.2, fit=True):
# ---> 29         X = self.df.drop(labels=(['class']), axis=1).as_matrix()
#      30         y = self.df['class'].as_matrix()
#      31         X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels ['class'] not contained in axis
